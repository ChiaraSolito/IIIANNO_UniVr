# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = pd.to_datetime(['23-03-2022','24-03-2022','25-03-2022','29-03-2022'])
y = [6,0,0,0]

# %%
# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()
